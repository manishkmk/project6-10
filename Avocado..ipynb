# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
df=pd.read_csv('avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1512          10  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# ...

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
# Unnamed: 0      1517 non-null int64
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 166.0+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
import pandas_profiling as pp
pp.ProfileReport(df)
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %% [markdown]
# ### In Data Analysis we will Analyze to find out the below stuff

# %% [raw]
# # In Data Analysis We will Analyze To Find out the below stuff
# 1.Missing Values
# 2.All The Numerical Variables
# 3.Distribution of the Numerical Variables
# 4.Categorical Variables
# 5.Cardinality of Categorical Variables
# 6.Outliers
# 7.Relationship between independent and dependent feature(AveragePrice)

# %% [markdown]
# # Missing Values

# %%
##  Here we will check the percentage of NaN values of eache feaure
## step 1- Maeke the list of feature which has missing values
features_with_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1]
## Step 2- print the feature name and percentage of missing values
for feature in features_with_nan:
    print(feature,np.round(df[feature].isnull().mean(),4),'%missing values')

# %% [markdown]
# ## Observation(s):

# %% [markdown]
# Luckily we don’t have any missing values and from the above AVOCADO data snapshot it also looks like we don’t need to format the data.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# # Observation(s):

# %% [markdown]
# Also with the help of Seaborn we are visualize there is no null/missing values in any features

# %% [markdown]
# ## Numerical Variables

# %%
#List of numerical variables
numerical_features=[feature for feature in df.columns if df[feature].dtypes!='O']

print('Number of numerical variables',len(numerical_features))

df[numerical_features].head()
# Out:
# Number of numerical variables 11
#    Unnamed_0  AveragePrice  Total_Volume     4046       4225    4770  \
# 0          0          1.33      64236.62  1036.74   54454.85   48.16
# 1          1          1.35      54876.98   674.28   44638.81   58.33
# 2          2          0.93     118220.22   794.70  109149.67  130.50
# 3          3          1.08      78992.15  1132.00   71976.41   72.58
# 4          4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total_Bags  Small_Bags  Large_Bags  XLarge_Bags  year
# 0     8696.87     8603.62       93.25          0.0  2015
# 1     9505.56     9408.07       97.49          0.0  2015
# 2     8145.35     8042.21      103.14          0.0  2015
# 3     5811.16     5677.40      133.76          0.0  2015
# 4     6183.95     5986.26      197.69          0.0  2015

# %%
#List of numerical variables
object_features=[feature for feature in df.columns if df[feature].dtypes=='O']

print('Number of numerical variables',len(object_features))

df[object_features].head()
# Out:
# Number of numerical variables 3
#          Date          type  region
# 0  27-12-2015  conventional  Albany
# 1  20-12-2015  conventional  Albany
# 2  13-12-2015  conventional  Albany
# 3  06-12-2015  conventional  Albany
# 4  29-11-2015  conventional  Albany

# %%
# list of variables that contain year information
year_feature = [feature for feature in df.columns if 'Date' in feature or 'year' in feature]

year_feature
# Out:
# ['Date', 'year']

# %%
# let's explore the content of these year variables
for feature in year_feature:
    print(feature, df[feature].unique())
# Out:
# Date ['27-12-2015' '20-12-2015' '13-12-2015' '06-12-2015' '29-11-2015'
#  '22-11-2015' '15-11-2015' '08-11-2015' '01-11-2015' '25-10-2015'
#  '18-10-2015' '11-10-2015' '04-10-2015' '27-09-2015' '20-09-2015'
#  '13-09-2015' '06-09-2015' '30-08-2015' '23-08-2015' '16-08-2015'
#  '09-08-2015' '02-08-2015' '26-07-2015' '19-07-2015' '12-07-2015'
#  '05-07-2015' '28-06-2015' '21-06-2015' '14-06-2015' '07-06-2015'
#  '31-05-2015' '24-05-2015' '17-05-2015' '10-05-2015' '03-05-2015'
#  '26-04-2015' '19-04-2015' '12-04-2015' '05-04-2015' '29-03-2015'
#  '22-03-2015' '15-03-2015' '08-03-2015' '01-03-2015' '22-02-2015'
#  '15-02-2015' '08-02-2015' '01-02-2015' '25-01-2015' '18-01-2015'
#  '11-01-2015' '04-01-2015' '25-12-2016' '18-12-2016' '11-12-2016'
#  '04-12-2016' '27-11-2016' '20-11-2016' '13-11-2016' '06-11-2016'
#  '30-10-2016' '23-10-2016' '16-10-2016' '09-10-2016' '02-10-2016'
#  '25-09-2016' '18-09-2016' '08-05-2016' '01-05-2016' '24-04-2016'
# ...

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price

df.groupby('Date')['AveragePrice'].median().plot()
plt.xlabel('AveragePrice')
plt.ylabel('Median AveragePrice')
plt.title("AveragePrice Price vs Date")
# Out:
# Text(0.5, 1.0, 'AveragePrice Price vs Date')

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_feature=[feature for feature in numerical_features if len(df[feature].unique())<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 0

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature+year_feature+['Unnamed']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 10

# %%
continuous_feature
# Out:
# ['Unnamed_0',
#  'AveragePrice',
#  'Total_Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total_Bags',
#  'Small_Bags',
#  'Large_Bags',
#  'XLarge_Bags']

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("AveragePrice")
    plt.title(feature)
    plt.show()

# %%
## we will use a Logrithmic Transformation
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(df[feature])
        data['AveragePrice']=np.log(df['AveragePrice'])
        plt.scatter(data[feature],data['AveragePrice'])
        plt.xlabel(feature)
        plt.ylabel('AveragePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ## Outliers

# %%
for feature in continuous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show();

# %% [markdown]
# ## Categorical Variables

# %%
categorical_features=[feature for feature in df.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['Date', 'type', 'region']

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# The feature is Date and number of categories are 104
# The feature is type and number of categories are 1
# The feature is region and number of categories are 51

# %%
## Find out the relationship between categorical variable and dependent feature AveragePrice
for feature in categorical_features:
    data=df.copy()
    data.groupby(feature)['AveragePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('AveragePrice')
    plt.title(feature)
    plt.show()

# %%
for feature in year_feature:
    if feature!='year':
    
        data=df.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data[feature]

        plt.scatter(data[feature],data['AveragePrice'])
        plt.xlabel(feature)
        plt.ylabel('AveragePrice')
        plt.show()

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#               Unnamed_0  AveragePrice  Total_Volume      4046      4225  \
# Unnamed_0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice  -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total_Volume   0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046           0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225           0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770           0.075647     -0.100567      0.934347  0.898570  0.927757
# Total_Bags     0.081007     -0.111597      0.967689  0.930395  0.951779
# Small_Bags     0.083485     -0.097682      0.960642  0.922278  0.943988
# Large_Bags     0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge_Bags   -0.050993     -0.048284      0.521717  0.474063  0.504718
# year          -0.012854      0.178683     -0.004189 -0.040439 -0.007254
#
#                   4770  Total_Bags  Small_Bags  Large_Bags  XLarge_Bags  \
# ...

# %%
df.describe()
# Out:
#          Unnamed_0  AveragePrice  Total_Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total_Bags    Small_Bags    Large_Bags    XLarge_Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We will be performing all the below steps in Feature Engineering

# %% [markdown]
# 1.Missing values
# 2.Temporal variables
# 3.Categorical variables: remove rare labels
# 4.Standarise the values of the variables to the same range

# %%
df.columns
# Out:
# Index(['Unnamed_0', 'Date', 'AveragePrice', 'Total_Volume', '4046', '4225',
#        '4770', 'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge_Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#Replace  to Nan
df['4770']=df[['4770']].replace(0,np.nan)

# %%
df['Large_Bags']=df[['Large_Bags']].replace(0,np.nan)

# %%
df['XLarge_Bags']=df[['XLarge_Bags']].replace(0,np.nan)

# %%
df.describe()
# Out:
#          Unnamed_0  AveragePrice  Total_Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total_Bags    Small_Bags    Large_Bags    XLarge_Bags  \
# count  1.516000e+03  1.517000e+03  1.517000e+03  1.517000e+03     719.000000
# mean   5.043874e+04  2.935974e+05  2.487736e+05  4.264205e+04    4603.263866
# ...

# %%
## Now lets check for numerical variables the contains missing values
numerical_with_nan=[feature for feature in df.columns if df[feature].isnull().sum() and df[feature].dtypes!='O']

## We will print the numerical nan variables and percentage of missing values

for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,np.around(df[feature].isnull().mean(),4)))
# Out:
# 4770: 0.0007% missing value
# Large_Bags: 0.0883% missing value
# XLarge_Bags: 0.526% missing value

# %%
## Replacing the numerical Missing Values

for feature in numerical_with_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    
    ## create a new feature to capture nan values
    df[feature+'nan']=np.where(df[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace=True)
    
df[numerical_with_nan].isnull().sum()
# Out:
# 4770           0
# Large_Bags     0
# XLarge_Bags    0
# dtype: int64

# %% [markdown]
# ## Numerical Variables

# %% [markdown]
# Since the numerical variables are skewed we will perform log normal distribution

# %%
df.describe()
# Out:
#          Unnamed_0  AveragePrice  Total_Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total_Bags    Small_Bags    Large_Bags    XLarge_Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.041058e+04  2.935974e+05  2.487736e+05  4.322368e+04    2478.172577
# ...

# %%
import numpy as np
num_features=['AveragePrice','4046','4225','4770']

for feature in num_features:
    df[feature]=np.log(df[feature])

# %%
df.head()
# Out:
#    Unnamed_0        Date  AveragePrice  Total_Volume      4046       4225  \
# 0          0  27-12-2015      0.285179      64236.62  6.943836  10.905127
# 1          1  20-12-2015      0.300105      54876.98  6.513645  10.706359
# 2          2  13-12-2015     -0.072571     118220.22  6.677965  11.600475
# 3          3  06-12-2015      0.076961      78992.15  7.031741  11.184094
# 4          4  29-11-2015      0.246860      51039.60  6.847453  10.688265
#
#        4770  Total_Bags  Small_Bags  Large_Bags  XLarge_Bags          type  \
# 0  3.874529     8696.87     8603.62       93.25       563.46  conventional
# 1  4.066117     9505.56     9408.07       97.49       563.46  conventional
# 2  4.871373     8145.35     8042.21      103.14       563.46  conventional
# 3  4.284689     5811.16     5677.40      133.76       563.46  conventional
# 4  4.327834     6183.95     5986.26      197.69       563.46  conventional
#
#    year  region  4770nan  Large_Bagsnan  XLarge_Bagsnan
# ...

# %%
df.describe()
# Out:
#          Unnamed_0  AveragePrice  Total_Volume         4046         4225  \
# count  1517.000000   1517.000000  1.517000e+03  1517.000000  1517.000000
# mean     26.995386      0.055717  1.601879e+06    11.215904    11.871661
# std      14.848287      0.186732  4.433143e+06     2.337337     1.703678
# min       0.000000     -0.713350  3.875074e+04     6.147870     7.486484
# 25%      14.000000     -0.020203  1.474700e+05     9.923307    10.632872
# 50%      29.000000      0.076961  4.027919e+05    11.311435    11.684059
# 75%      39.000000      0.173953  9.819751e+05    12.841534    13.092214
# max      51.000000      0.518794  4.465546e+07    16.756419    16.757656
#
#               4770    Total_Bags    Small_Bags    Large_Bags    XLarge_Bags  \
# count  1517.000000  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean      8.560106  2.935974e+05  2.487736e+05  4.322368e+04    2478.172577
# std       2.572986  7.579765e+05  6.474765e+05  1.180204e+05    7373.780492
# ...

# %% [markdown]
# ## Handling the Categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['type']=le.fit_transform(df['type'])
df['region']=le.fit_transform(df['region'])
df.head()
# Out:
#    Unnamed_0        Date  AveragePrice  Total_Volume      4046       4225  \
# 0          0  27-12-2015      0.285179      64236.62  6.943836  10.905127
# 1          1  20-12-2015      0.300105      54876.98  6.513645  10.706359
# 2          2  13-12-2015     -0.072571     118220.22  6.677965  11.600475
# 3          3  06-12-2015      0.076961      78992.15  7.031741  11.184094
# 4          4  29-11-2015      0.246860      51039.60  6.847453  10.688265
#
#        4770  Total_Bags  Small_Bags  Large_Bags  XLarge_Bags  type  year  \
# 0  3.874529     8696.87     8603.62       93.25       563.46     0  2015
# 1  4.066117     9505.56     9408.07       97.49       563.46     0  2015
# 2  4.871373     8145.35     8042.21      103.14       563.46     0  2015
# 3  4.284689     5811.16     5677.40      133.76       563.46     0  2015
# 4  4.327834     6183.95     5986.26      197.69       563.46     0  2015
#
#    region  4770nan  Large_Bagsnan  XLarge_Bagsnan
# ...

# %%
for feature in categorical_features:
    temp=df.groupby(feature)['AveragePrice'].count()/len(df)
    temp_df=temp[temp>0.01].index
    df[feature]=np.where(df[feature].isin(temp_df),df[feature],'Rare_var')

# %%
df.head()
# Out:
#    Unnamed_0        Date  AveragePrice  Total_Volume      4046       4225  \
# 0          0  27-12-2015      0.285179      64236.62  6.943836  10.905127
# 1          1  20-12-2015      0.300105      54876.98  6.513645  10.706359
# 2          2  13-12-2015     -0.072571     118220.22  6.677965  11.600475
# 3          3  06-12-2015      0.076961      78992.15  7.031741  11.184094
# 4          4  29-11-2015      0.246860      51039.60  6.847453  10.688265
#
#        4770  Total_Bags  Small_Bags  Large_Bags  XLarge_Bags type  year  \
# 0  3.874529     8696.87     8603.62       93.25       563.46    0  2015
# 1  4.066117     9505.56     9408.07       97.49       563.46    0  2015
# 2  4.871373     8145.35     8042.21      103.14       563.46    0  2015
# 3  4.284689     5811.16     5677.40      133.76       563.46    0  2015
# 4  4.327834     6183.95     5986.26      197.69       563.46    0  2015
#
#   region  4770nan  Large_Bagsnan  XLarge_Bagsnan
# ...

# %%
for feature in categorical_features:
    labels_ordered=df.groupby([feature])['AveragePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df.head()
# Out:
#    Unnamed_0  Date  AveragePrice  Total_Volume      4046       4225      4770  \
# 0          0    18      0.285179      64236.62  6.943836  10.905127  3.874529
# 1          1    32      0.300105      54876.98  6.513645  10.706359  4.066117
# 2          2     3     -0.072571     118220.22  6.677965  11.600475  4.871373
# 3          3     1      0.076961      78992.15  7.031741  11.184094  4.284689
# 4          4    36      0.246860      51039.60  6.847453  10.688265  4.327834
#
#    Total_Bags  Small_Bags  Large_Bags  XLarge_Bags  type  year  region  \
# 0     8696.87     8603.62       93.25       563.46     0  2015      37
# 1     9505.56     9408.07       97.49       563.46     0  2015      37
# 2     8145.35     8042.21      103.14       563.46     0  2015      37
# 3     5811.16     5677.40      133.76       563.46     0  2015      37
# 4     6183.95     5986.26      197.69       563.46     0  2015      37
#
#    4770nan  Large_Bagsnan  XLarge_Bagsnan
# ...

# %%
df.describe()
# Out:
#          Unnamed_0         Date  AveragePrice  Total_Volume         4046  \
# count  1517.000000  1517.000000   1517.000000  1.517000e+03  1517.000000
# mean     26.995386    30.184575      0.055717  1.601879e+06    11.215904
# std      14.848287    16.838013      0.186732  4.433143e+06     2.337337
# min       0.000000     0.000000     -0.713350  3.875074e+04     6.147870
# 25%      14.000000    16.000000     -0.020203  1.474700e+05     9.923307
# 50%      29.000000    31.000000      0.076961  4.027919e+05    11.311435
# 75%      39.000000    46.000000      0.173953  9.819751e+05    12.841534
# max      51.000000    52.000000      0.518794  4.465546e+07    16.756419
#
#               4225         4770    Total_Bags    Small_Bags    Large_Bags  \
# count  1517.000000  1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     11.871661     8.560106  2.935974e+05  2.487736e+05  4.322368e+04
# std       1.703678     2.572986  7.579765e+05  6.474765e+05  1.180204e+05
# ...

# %% [markdown]
# ## Feature Scaling

# %%
feature_scale=[feature for feature in df.columns if feature not in ['Unnamed_0','AveragePrice']]
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit_transform(df[feature_scale])
# Out:
# array([[-0.72387359, -0.34696593, -1.82835304, ..., -0.02568327,
#         -0.3112729 ,  0.94921152],
#        [ 0.10785262, -0.34907791, -2.01246553, ..., -0.02568327,
#         -0.3112729 ,  0.94921152],
#        [-1.61500881, -0.33478463, -1.94214044, ..., -0.02568327,
#         -0.3112729 ,  0.94921152],
#        ...,
#        [ 1.29603292, -0.32120275, -0.20183865, ..., -0.02568327,
#         -0.3112729 , -1.05350597],
#        [ 1.29603292, -0.31878364, -0.13571848, ..., -0.02568327,
#         -0.3112729 ,  0.94921152],
#        [ 1.29603292, -0.3201721 , -0.23292521, ..., -0.02568327,
#         -0.3112729 ,  0.94921152]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([df[['AveragePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(df[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
data.head()
# Out:
#    AveragePrice      Date  Total_Volume      4046      4225      4770  \
# 0      0.285179 -0.723874     -0.346966 -1.828353 -0.567509 -1.821667
# 1      0.300105  0.107853     -0.349078 -2.012466 -0.684218 -1.747181
# 2     -0.072571 -1.615009     -0.334785 -1.942140 -0.159229 -1.434112
# 3      0.076961 -1.733827     -0.343636 -1.790732 -0.403711 -1.662204
# 4      0.246860  0.345489     -0.349944 -1.869603 -0.694842 -1.645430
#
#    Total_Bags  Small_Bags  Large_Bags  XLarge_Bags  type      year    region  \
# 0   -0.375994   -0.371055   -0.365570    -0.259751   0.0 -0.441008  1.292537
# 1   -0.374927   -0.369812   -0.365534    -0.259751   0.0 -0.441008  1.292537
# 2   -0.376722   -0.371922   -0.365486    -0.259751   0.0 -0.441008  1.292537
# 3   -0.379802   -0.375576   -0.365226    -0.259751   0.0 -0.441008  1.292537
# 4   -0.379310   -0.375098   -0.364684    -0.259751   0.0 -0.441008  1.292537
#
#     4770nan  Large_Bagsnan  XLarge_Bagsnan
# ...

# %%
x = data.drop('AveragePrice',axis=1)
y = data['AveragePrice']

# %%
x.head()
# Out:
#        Date  Total_Volume      4046      4225      4770  Total_Bags  \
# 0 -0.723874     -0.346966 -1.828353 -0.567509 -1.821667   -0.375994
# 1  0.107853     -0.349078 -2.012466 -0.684218 -1.747181   -0.374927
# 2 -1.615009     -0.334785 -1.942140 -0.159229 -1.434112   -0.376722
# 3 -1.733827     -0.343636 -1.790732 -0.403711 -1.662204   -0.379802
# 4  0.345489     -0.349944 -1.869603 -0.694842 -1.645430   -0.379310
#
#    Small_Bags  Large_Bags  XLarge_Bags  type      year    region   4770nan  \
# 0   -0.371055   -0.365570    -0.259751   0.0 -0.441008  1.292537 -0.025683
# 1   -0.369812   -0.365534    -0.259751   0.0 -0.441008  1.292537 -0.025683
# 2   -0.371922   -0.365486    -0.259751   0.0 -0.441008  1.292537 -0.025683
# 3   -0.375576   -0.365226    -0.259751   0.0 -0.441008  1.292537 -0.025683
# 4   -0.375098   -0.364684    -0.259751   0.0 -0.441008  1.292537 -0.025683
#
#    Large_Bagsnan  XLarge_Bagsnan
# 0      -0.311273        0.949212
# 1      -0.311273        0.949212
# ...

# %%
y.head()
# Out:
# 0    0.285179
# 1    0.300105
# 2   -0.072571
# 3    0.076961
# 4    0.246860
# Name: AveragePrice, dtype: float64

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=3)

# %%
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X=pca.transform(x)

# %%
X.shape,y.shape
# Out:
# ((1517, 3), (1517,))

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1],c='y',cmap='plasma')

# %%
sns.distplot(y)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.10, random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((1365, 3), (1365,))

# %%
x_test.shape,y_test.shape
# Out:
# ((152, 3), (152,))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso,Ridge,LinearRegression,LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(35,100):
    x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state, "is",max_r_score)
# Out:
# max r2 score corresponding to 36 is 0.43144294071064115

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print ("R2 of Linear Regresson:", regressor.score(x_train,y_train))
# Out:
# R2 of Linear Regresson: 0.3681655413864869

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 100}
# -0.030783979758868193

# %% [markdown]
# ## Lasso Regression

# %%
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lasso_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
lasso_regressor.fit(X,y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# {'alpha': 0.01}
# -0.032937390235942096

# %% [markdown]
# ## KNeighborsRegressor

# %%
KNN=KNeighborsRegressor()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
print ("R2 of KNN Regresson:", KNN.score(x_train,y_train))
# Out:
# R2 of KNN Regresson: 0.7632012351026555

# %% [markdown]
# ## SVR

# %%
sv=SVR()
sv.fit(x_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print ("R2 of SVR Regresson:", sv.score(x_train,y_train))
# Out:
# R2 of SVR Regresson: 0.6181486357101691

# %% [markdown]
# ## RandomForestRegressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
print ("R2 of RandomForest Regresson:", rf.score(x_train,y_train))
# Out:
# R2 of RandomForest Regresson: 0.8868364650018298

# %%
#predict the value
pred=rf.predict(x_test)
print("Predicted result price:",pred)
print("actual price",y_test)
# Out:
# Predicted result price: [ 2.85178778e-01  6.39920571e-02 -3.82514348e-01 -4.99795371e-02
#   2.24182108e-01  2.41053051e-03  1.49998046e-01 -2.44945606e-01
#  -4.45389557e-01  7.40557311e-02  1.60469784e-01  1.87600626e-01
#   1.81808104e-01  7.63723653e-03  1.69395510e-01  1.33357573e-01
#  -1.95246809e-02  1.80239298e-01  1.64411184e-01  1.97057108e-01
#   1.92604579e-02  4.82364374e-03 -1.86329578e-01  1.35284834e-01
#   2.44699353e-01 -6.94064137e-03  9.49109303e-02 -3.15169662e-02
#   1.47703402e-01 -5.20418556e-02  1.28492128e-01 -2.75342930e-04
#  -6.37230326e-03 -9.95986256e-02 -1.53407270e-02 -8.01982091e-02
#   4.57259805e-02  3.10529075e-01 -2.22627308e-01 -3.62615098e-02
#   2.81873808e-01  2.45307417e-01 -3.53879774e-01  1.58321013e-02
#   2.18947665e-01  2.56091576e-01  7.63052383e-02 -1.57700243e-01
#   4.38234904e-02 -3.27748529e-02  1.94708173e-01  2.95588022e-02
#   2.92787932e-01  1.49354094e-02  2.12611698e-01 -2.62749439e-01
# ...

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))


print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 0.0367751889798392
# Mean squared error: 0.0030712821369720204
# Root Mean Squared Error: 0.055419149551143604

# %%
import pickle
#save the traind model
saved_model=pickle.dumps(rf)
#Load the pickel data
rf_from_pickle=pickle.loads(saved_model)
